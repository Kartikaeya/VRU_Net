# %%
# %matplotlib inline
import torch
import json
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
from Data_Loader import Pose_Dataset, my_collate, RandomFlip, RandomRotate, ToTensor
from torchvision import transforms, utils

# %%
f = open('../annotations/vru_keypoints_val_copy.json', 'r')
keypoints = json.load(f)
f.close()

# %%
keypoints['annotations'][0]['bbox']
# Out:
# [107, 81, 234, 373]

# %%
kpts = np.array(keypoints['annotations'][0]['keypoints'], dtype = np.int32)
kpts = np.reshape(kpts, (17,3))
kpts
# Out:
# array([[279, 120,   1],
#        [275, 112,   1],
#        [283, 112,   2],
#        [246, 115,   1],
#        [272, 114,   2],
#        [213, 151,   2],
#        [292, 151,   2],
#        [165, 172,   2],
#        [322, 217,   2],
#        [135, 170,   2],
#        [332, 250,   2],
#        [235, 246,   2],
#        [277, 247,   2],
#        [233, 342,   2],
#        [283, 342,   2],
#        [230, 439,   1],
#        [293, 438,   1]])

# %%
img = cv2.imread('../images/val/000000026035.jpg')
img = cv2.resize(img, (0, 0), fx = 0.2 , fy = 0.2)
plt.imshow(img[:, :, [2, 1, 0]])

# %%
x1 = int(bbox[0])
y1 = int(bbox[1])
x2 = int(bbox[0] + bbox[2])
y2 = int(bbox[1] + bbox[3])
img = cv2.rectangle(img, (x1, y1), (x2, y2), [225, 0, 0], 2)
img2 = img[bbox[1]:(bbox[1]+bbox[3]), bbox[0]:(bbox[0]+bbox[2])]
plt.imshow(img2[:, :, [2, 1, 0]])
plt.show()

# %%
def get_gaussian(output_shape, x, y, sigma):
        xx, yy= np.meshgrid(np.arange(output_shape[1]), np.arange(output_shape[0]))
        return ((1/(np.sqrt(2*np.pi*sigma**2)))*np.exp(-(yy-y)**2/(2*sigma**2)))*((1/(np.sqrt(2*np.pi*sigma**2)))*np.exp(-(xx - x)**2/(2*sigma**2)))

# %%
kpts[:, 0] = kpts[:, 0] - x1
kpts[:, 1] = kpts[:, 1] - y1

# %%
# heatmap = get_gaussian(img2.shape,kpts[] )

img2 = cv2.circle(img2, (kpts[16, 0], kpts[16, 1]), 4, (0, 0, 255), -1)
plt.imshow(img2[:, :, [2, 1, 0]])
plt.show()

# %%
gaussian = get_gaussian(img2.shape, kpts[14,0], kpts[14, 1], sigma = 15)

# %%
plt.imshow(img2[:, :, [2, 1, 0]])
plt.imshow(gaussian, alpha = 0.5)

# %%
dataset = Pose_Dataset(annotations_path = '../annotations/vru_keypoints_val_copy.json',
                      img_path = '../images/val',
                      transform = transforms.Compose([
                          RandomFlip(0.5),
                          RandomRotate(degree = 10),
                          ToTensor()
                      ]))

# %%
sample = dataset[6]
plt.imshow(sample['image'][:, :, [2, 1, 0]])
