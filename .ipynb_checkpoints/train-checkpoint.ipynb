# %%
# %matplotlib inline
import torch
import torchvision
import json
import cv2
import numpy as np
import os

from matplotlib import pyplot as plt

from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter 
from torchvision import transforms, utils
from torchsummary import summary

from Data_Loader import Pose_Dataset, my_collate, RandomFlip, RandomRotate, ToTensor
from model import VRUNet
from Modify_annotations import scale_annotations

# %%
# set parameters here before training

# fraction of validation dataset, default = 5%
# val_fraction = 0.05 

# train, val batch size
train_batch_size = 8
val_batch_size = 16

# use multiple GPUs if available, default = True
multi_GPU = True

# number of epochs
num_epochs = 20

# annotations and image path
annotations_path = 'Data/COCO/annotations/person_keypoints_train2017.json'
img_path = 'Data/COCO/train2017/'

val_annotations_path = 'Data/COCO/annotations/person_keypoints_val2017.json'
val_img_path = 'Data/COCO/val2017/'

# don't modify this
# scaled_annotations_path = annotations_path[:-5] + '_copy.json'

# %%
# scale_annotations(annotations_path, scaled_annotations_path)

# %%
torch.cuda.empty_cache()

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
train_dataset = Pose_Dataset(annotations_path = annotations_path,
                      img_path = img_path,
                      transform = transforms.Compose([
                          RandomFlip(0.5),
                          RandomRotate(degree = 10),
                          ToTensor()
                      ]),
                       dataset = 'COCO'
                      )
val_dataset = Pose_Dataset(annotations_path = val_annotations_path,
                           img_path = val_img_path,
                           transform = transforms.Compose([
                               RandomFlip(0.5),
                               RandomRotate(degree = 10),
                               ToTensor()
                           ]),
                           dataset = 'COCO'
                          )

print("No. of images in training set :",len(train_dataset))
print("No. of images in validation set :",len(val_dataset))

# train_dataset, val_dataset = torch.utils.data.random_split(dataset, [len_train_images, len_val_images]) 

train_dataloader = DataLoader(train_dataset, batch_size = train_batch_size, shuffle = False, collate_fn = my_collate)
val_dataloader = DataLoader(val_dataset, batch_size = val_batch_size, shuffle = False, collate_fn = my_collate)
# Out:
# No. of images in training set : 262465
# No. of images in validation set : 11004

# %%
# visualize batch of images from dataloader
iterator = iter(train_dataloader)
images, target = next(iterator)
# images, target = next(iterator)
fig = plt.figure(figsize = (20,20))
axes = []
for i in range(images.shape[0]):
    img = np.transpose(images[i].cpu(), (1,2,0))
    axes.append(fig.add_subplot(4, 4, i+1))
    plt.imshow(img[:, :, [2, 1, 0]])
    plt.imshow(target[i][16].cpu(), alpha = 0.5)
plt.show()

# %%
model = VRUNet()
if torch.cuda.device_count() > 1 and multi_GPU:
    print("Using ",torch.cuda.device_count(), " GPUs for training!!")
    model = nn.DataParallel(model)

model.to(device)
# Out:
# VRUNet(
#   (Backbone): BackBone(
#     (bb1): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (batchnorm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 16, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (batchnorm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (3): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (bb2): Sequential(
#       (0): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (3): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (bb3): Sequential(
#       (0): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (3): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (skip1): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (skip2): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (upsample1): Sequential(
#       (0): DeConv(
#         (convTranspose): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): DeConv(
#         (convTranspose): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (3): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (4): Conv(
#         (conv): Conv2d(32, 17, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#   )
#   (Unet_module): ModuleList(
#     (0): Unet(
#       (conv1): Conv(
#         (conv): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (conv2): ModuleList(
#         (0): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (1): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (2): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (3): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#       )
#       (conv3): ModuleList(
#         (0): DeConv(
#           (convTranspose): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): DeConv(
#           (convTranspose): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): DeConv(
#           (convTranspose): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (3): DeConv(
#           (convTranspose): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv4): ModuleList(
#         (0): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (1): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (2): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (3): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#       )
#       (conv5): Conv(
#         (conv): Conv2d(32, 17, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (1): Unet(
#       (conv1): Conv(
#         (conv): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (conv2): ModuleList(
#         (0): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (1): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (2): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (3): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#       )
#       (conv3): ModuleList(
#         (0): DeConv(
#           (convTranspose): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): DeConv(
#           (convTranspose): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): DeConv(
#           (convTranspose): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (3): DeConv(
#           (convTranspose): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv4): ModuleList(
#         (0): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (1): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (2): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (3): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#       )
#       (conv5): Conv(
#         (conv): Conv2d(32, 17, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (2): Unet(
#       (conv1): Conv(
#         (conv): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (conv2): ModuleList(
#         (0): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (1): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (2): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (3): Downsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (2): Conv(
#               (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(2, 2))
#               (batchnorm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#       )
#       (conv3): ModuleList(
#         (0): DeConv(
#           (convTranspose): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): DeConv(
#           (convTranspose): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): DeConv(
#           (convTranspose): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (3): DeConv(
#           (convTranspose): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1))
#           (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv4): ModuleList(
#         (0): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (1): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (2): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#         (3): Upsample(
#           (conv): Sequential(
#             (0): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#             (1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU()
#             )
#           )
#         )
#       )
#       (conv5): Conv(
#         (conv): Conv2d(32, 17, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(17, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#   )
# )

# %%
# Setting up tensorboard
writer = SummaryWriter('runs/VRU_Net_experiment1')
dataiter = iter(train_dataloader)
images, targets = dataiter.next()
img_grid = torchvision.utils.make_grid(images)
writer.add_image('train_loader image batch', img_grid)

# %%
writer.add_graph(model, images)
writer.close()
# Out:
# C:\Users\Kartikaeya\Anaconda3\lib\site-packages\torch\nn\functional.py:2506: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# CUDA out of memory. Tried to allocate 20.00 MiB (GPU 0; 4.00 GiB total capacity; 2.80 GiB already allocated; 1.27 MiB free; 2.93 GiB reserved in total by PyTorch)
# Error occurs, No graph saved
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-5a2374704e86> in <module>
# ----> 1 writer.add_graph(model, images)
#       2 writer.close()
#
# ~\Anaconda3\lib\site-packages\torch\utils\tensorboard\writer.py in add_graph(self, model, input_to_model, verbose)
#     705         if hasattr(model, 'forward'):
#     706             # A valid PyTorch model should have a 'forward' method
# --> 707             self._get_file_writer().add_graph(graph(model, input_to_model, verbose))
#     708         else:
#     709             # Caffe2 models do not have the 'forward' method
#
# ~\Anaconda3\lib\site-packages\torch\utils\tensorboard\_pytorch_graph.py in graph(model, args, verbose)
#     289             print(e)
#     290             print('Error occurs, No graph saved')
# --> 291             raise e
#     292
#     293     if verbose:
#
# ~\Anaconda3\lib\site-packages\torch\utils\tensorboard\_pytorch_graph.py in graph(model, args, verbose)
#     283     with torch.onnx.set_training(model, False):  # TODO: move outside of torch.onnx?
#     284         try:
# --> 285             trace = torch.jit.trace(model, args)
#     286             graph = trace.graph
#     287             torch._C._jit_pass_inline(graph)
#
# ~\Anaconda3\lib\site-packages\torch\jit\__init__.py in trace(func, example_inputs, optimize, check_trace, check_inputs, check_tolerance, _force_outplace, _module_class, _compilation_unit)
#     880         return trace_module(func, {'forward': example_inputs}, None,
#     881                             check_trace, wrap_check_inputs(check_inputs),
# --> 882                             check_tolerance, _force_outplace, _module_class)
#     883
#     884     if (hasattr(func, '__self__') and isinstance(func.__self__, torch.nn.Module) and
#
# ~\Anaconda3\lib\site-packages\torch\jit\__init__.py in trace_module(mod, inputs, optimize, check_trace, check_inputs, check_tolerance, _force_outplace, _module_class, _compilation_unit)
#    1032             func = mod if method_name == "forward" else getattr(mod, method_name)
#    1033             example_inputs = make_tuple(example_inputs)
# -> 1034             module._c._create_method_from_trace(method_name, func, example_inputs, var_lookup_fn, _force_outplace)
#    1035             check_trace_method = module._c._get_method(method_name)
#    1036
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     528                 input = result
#     529         if torch._C._get_tracing_state():
# --> 530             result = self._slow_forward(*input, **kwargs)
#     531         else:
#     532             result = self.forward(*input, **kwargs)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _slow_forward(self, *input, **kwargs)
#     514                 recording_scopes = False
#     515         try:
# --> 516             result = self.forward(*input, **kwargs)
#     517         finally:
#     518             if recording_scopes:
#
# ~\Desktop\Internship\Pose_Estimation\Livewire\Pose_Estimation_LiveWire\model.py in forward(self, x)
#     204         for i in range(3):
#     205             x = torch.cat((x, input_img), 1)
# --> 206             x = self.Unet_module[i](x)
#     207             x = F.interpolate(x, (input_img.shape[2], input_img.shape[3]), mode = 'bilinear')
#     208             confidence_maps.append(x)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     528                 input = result
#     529         if torch._C._get_tracing_state():
# --> 530             result = self._slow_forward(*input, **kwargs)
#     531         else:
#     532             result = self.forward(*input, **kwargs)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _slow_forward(self, *input, **kwargs)
#     514                 recording_scopes = False
#     515         try:
# --> 516             result = self.forward(*input, **kwargs)
#     517         finally:
#     518             if recording_scopes:
#
# ~\Desktop\Internship\Pose_Estimation\Livewire\Pose_Estimation_LiveWire\model.py in forward(self, x)
#     180             x = torch.cat((x, interpolated_layer), 1)
#     181 #             print(x.shape)
# --> 182             x = self.conv4[i](x)
#     183         x = self.conv5(x)
#     184         return x
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     528                 input = result
#     529         if torch._C._get_tracing_state():
# --> 530             result = self._slow_forward(*input, **kwargs)
#     531         else:
#     532             result = self.forward(*input, **kwargs)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _slow_forward(self, *input, **kwargs)
#     514                 recording_scopes = False
#     515         try:
# --> 516             result = self.forward(*input, **kwargs)
#     517         finally:
#     518             if recording_scopes:
#
# ~\Desktop\Internship\Pose_Estimation\Livewire\Pose_Estimation_LiveWire\model.py in forward(self, x)
#     149         )
#     150     def forward(self, x):
# --> 151         x = self.conv(x)
#     152         return x
#     153
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     528                 input = result
#     529         if torch._C._get_tracing_state():
# --> 530             result = self._slow_forward(*input, **kwargs)
#     531         else:
#     532             result = self.forward(*input, **kwargs)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _slow_forward(self, *input, **kwargs)
#     514                 recording_scopes = False
#     515         try:
# --> 516             result = self.forward(*input, **kwargs)
#     517         finally:
#     518             if recording_scopes:
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     528                 input = result
#     529         if torch._C._get_tracing_state():
# --> 530             result = self._slow_forward(*input, **kwargs)
#     531         else:
#     532             result = self.forward(*input, **kwargs)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _slow_forward(self, *input, **kwargs)
#     514                 recording_scopes = False
#     515         try:
# --> 516             result = self.forward(*input, **kwargs)
#     517         finally:
#     518             if recording_scopes:
#
# ~\Desktop\Internship\Pose_Estimation\Livewire\Pose_Estimation_LiveWire\model.py in forward(self, x)
#      29             self.relu = nn.ReLU()
#      30     def forward(self, x):
# ---> 31         x = self.conv(x)
#      32         if self.is_bn:
#      33             x = self.batchnorm(x)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     528                 input = result
#     529         if torch._C._get_tracing_state():
# --> 530             result = self._slow_forward(*input, **kwargs)
#     531         else:
#     532             result = self.forward(*input, **kwargs)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _slow_forward(self, *input, **kwargs)
#     514                 recording_scopes = False
#     515         try:
# --> 516             result = self.forward(*input, **kwargs)
#     517         finally:
#     518             if recording_scopes:
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# RuntimeError: CUDA out of memory. Tried to allocate 20.00 MiB (GPU 0; 4.00 GiB total capacity; 2.80 GiB already allocated; 1.27 MiB free; 2.93 GiB reserved in total by PyTorch)

# %%
torch.cuda.empty_cache()

# %%
#train the neural network finally
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
loss_func = torch.nn.MSELoss(reduction = 'sum')

i = 0
prev_epoch = 0
for epoch in range(num_epochs):
    model.train()
    prev_epoch += i
    i = 0
    for images, target in train_dataloader:
        i += 1
        if(images.shape[0] == 0 or images.shape[2] > 550 or images.shape[3] > 550):
            i -= 1
            continue
        print("batch number : ",i, "epoch : ", epoch, " tensor size = ", images.shape, "memory usage = ", torch.cuda.memory_allocated())
        optimizer.zero_grad()
        pred = model(images)
#         loss = 25*loss_func(pred[:, 0:17], target[:, 0:17]) + 150*loss_func(pred[:, 17:34], target[:, 17:34]) + 500*loss_func(pred[:, 34:51], target[:, 34:51]) +  1000*loss_func(pred[:, 51:68], target[:, 51:68])
        loss = (loss_func(pred, target*((images.shape[2]*images.shape[3]) / 6400)))
        loss.backward()
        optimizer.step()
        
        writer.add_scalar('train_loss', loss.item(), prev_epoch + i)
#         running_train_loss += loss.cpu().detach().item()
        
        del pred, images, target, loss
        
        
        # write train, val losses to tensorboard
        if i%1000 == 999:
            

            model.eval()
            with torch.no_grad():
                k = 0
                valid_loss = 0
                for img, trgt in val_dataloader:
                    if(k > 100):
                        break
                    if(img.shape[0] == 0):
                        continue
                    print("val batch number : ",k, " tensor size = ", img.shape, "memory usage = ", torch.cuda.memory_allocated())
                    valid_loss += loss_func(model(img), trgt)* ((img.shape[2]*img.shape[3]) / 6400)
# val batch number :  0  tensor size =  torch.Size([3, 3, 418, 353]) memory usage =  576884736
# val batch number :  1  tensor size =  torch.Size([5, 3, 473, 513]) memory usage =  795851776
# val batch number :  2  tensor size =  torch.Size([1, 3, 321, 152]) memory usage =  465026048
# val batch number :  3  tensor size =  torch.Size([5, 3, 553, 351]) memory usage =  726795776
# val batch number :  4  tensor size =  torch.Size([7, 3, 361, 399]) memory usage =  737519104
# val batch number :  5  tensor size =  torch.Size([3, 3, 478, 362]) memory usage =  598596096
# val batch number :  6  tensor size =  torch.Size([8, 3, 369, 235]) memory usage =  648311296
# val batch number :  7  tensor size =  torch.Size([5, 3, 338, 241]) memory usage =  566839296
# val batch number :  8  tensor size =  torch.Size([1, 3, 246, 126]) memory usage =  459972096
# val batch number :  9  tensor size =  torch.Size([4, 3, 255, 204]) memory usage =  510263808
# val batch number :  10  tensor size =  torch.Size([5, 3, 396, 360]) memory usage =  653604352
# val batch number :  11  tensor size =  torch.Size([5, 3, 367, 401]) memory usage =  660146688
# val batch number :  12  tensor size =  torch.Size([5, 3, 410, 232]) memory usage =  586381824
# val batch number :  13  tensor size =  torch.Size([1, 3, 355, 202]) memory usage =  471534592
# val batch number :  14  tensor size =  torch.Size([1, 3, 285, 124]) memory usage =  461206016
# val batch number :  15  tensor size =  torch.Size([1, 3, 407, 129]) memory usage =  466479104
# val batch number :  16  tensor size =  torch.Size([2, 3, 507, 274]) memory usage =  530074624
# val batch number :  17  tensor size =  torch.Size([2, 3, 407, 346]) memory usage =  531156480
# val batch number :  18  tensor size =  torch.Size([3, 3, 274, 130]) memory usage =  481517568
# val batch number :  19  tensor size =  torch.Size([4, 3, 260, 108]) memory usage =  483274240
# val batch number :  20  tensor size =  torch.Size([2, 3, 251, 159]) memory usage =  473837568
# val batch number :  21  tensor size =  torch.Size([2, 3, 405, 276]) memory usage =  514660352
# val batch number :  22  tensor size =  torch.Size([1, 3, 185, 57]) memory usage =  454164480
# val batch number :  23  tensor size =  torch.Size([3, 3, 191, 103]) memory usage =  468654592
# val batch number :  24  tensor size =  torch.Size([3, 3, 467, 368]) memory usage =  597590528
# val batch number :  25  tensor size =  torch.Size([5, 3, 612, 489]) memory usage =  876129792
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-bf3108b39f1b> in <module>
#      36                 k = 0
#      37                 valid_loss = 0
# ---> 38                 for img, trgt in val_dataloader:
#      39                     if(k > 100):
#      40                         break
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# ~\Anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
# ---> 47         return self.collate_fn(data)
#
# ~\Desktop\Internship\Pose_Estimation\Livewire\Pose_Estimation_LiveWire\Data_Loader.py in my_collate(Batch)
#     118         mini_batch[i, :, top_padding:(top_padding + img.shape[1]),left_padding:(left_padding + img.shape[2])] = img
#     119         for j, batch in enumerate(item['target']):
# --> 120             mini_batch_target[i, 17*j:(17*j+17), top_padding:(top_padding + img.shape[1]),left_padding:(left_padding + img.shape[2])] = batch
#     121         i += 1
#     122
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), "trained_models/first_model_3.pth")
print("finished training!!")
# Out:
# finished training!!
